# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/vmajber/R---lend/master/combined2.csv')

# %%
df.head()
# Out:
#          X  loan_amnt  funded_amnt_inv        term int_rate  installment  \
# 0   438169     4500.0           4500.0   36 months   10.99%       147.31
# 1   673358    20000.0          20000.0   36 months    7.89%       625.72
# 2  1441301    21600.0          21600.0   36 months   16.02%       759.61
# 3   459303    20000.0          19950.0   36 months   11.99%       664.20
# 4  1731712    25000.0          25000.0   60 months   14.08%       582.75
#
#   grade sub_grade                   emp_title home_ownership  ...  issue_d  \
# 0     B        B2              Enrolled Agent       MORTGAGE  ...   Mar-14
# 1     A        A5                     Manager           RENT  ...   Jul-15
# 2     C        C5  Legal Administrative Asst.       MORTGAGE  ...   Jun-17
# 3     B        B3         Sr. Specialist, Tax           RENT  ...   Jan-14
# 4     C        C3              Crane Operator           RENT  ...   Oct-17
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

beso=LabelEncoder()
df['grade'] = beso.fit_transform(df['grade'])
tul=LabelEncoder()
df[ 'home_ownership'] = tul.fit_transform(df[ 'home_ownership'])
fl = LabelEncoder()
df['term'] = fl.fit_transform(df['term'].astype(str))
al=LabelEncoder()
df['addr_state'] = al.fit_transform(df['addr_state'])
purp=LabelEncoder()
df['purpose'] = purp.fit_transform(df['purpose'])
subg=LabelEncoder()
df['sub_grade'] = subg.fit_transform(df['sub_grade'])

# %%
df.head()
# Out:
#          X  loan_amnt  funded_amnt_inv  term int_rate  installment  grade  \
# 0   438169     4500.0           4500.0     0   10.99%       147.31      1
# 1   673358    20000.0          20000.0     0    7.89%       625.72      0
# 2  1441301    21600.0          21600.0     0   16.02%       759.61      2
# 3   459303    20000.0          19950.0     0   11.99%       664.20      1
# 4  1731712    25000.0          25000.0     1   14.08%       582.75      2
#
#    sub_grade                   emp_title  home_ownership  ...  issue_d  \
# 0          6              Enrolled Agent               1  ...   Mar-14
# 1          4                     Manager               3  ...   Jul-15
# 2         14  Legal Administrative Asst.               1  ...   Jun-17
# 3          7         Sr. Specialist, Tax               3  ...   Jan-14
# 4         12              Crane Operator               3  ...   Oct-17
#
#    loan_status pymnt_plan                                               desc  \
# ...

# %%
from google.colab import files

df.to_csv('df.csv')
files.download('df.csv')
